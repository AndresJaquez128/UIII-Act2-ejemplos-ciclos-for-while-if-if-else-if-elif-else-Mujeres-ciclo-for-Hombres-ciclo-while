# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresJaquez128/UIII-Act2-ejemplos-ciclos-for-while-if-if-else-if-elif-else-Mujeres-ciclo-for-Hombres-ciclo-while/blob/main/UIII_Act2_ejemplos_ciclos_while_Andres_0074.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Jaquez Andres NL = 27 FECHA 11/05/2026
# ## Ciclo While
# #1. Contar del 1 al 5
#
# ##Descripción:
# ##El ciclo while repite instrucciones mientras una condición sea verdadera.
#
# ##Situación:
# ##Mostrar números consecutivos en pantalla.

# %%
# Programa realizado por Andres Jaquez NL = 27

# Se solicita hasta qué número quiere contar el usuario
limite = int(input("Ingresa el número límite: "))

# Variable contador
contador = 1

# El ciclo continuará mientras el contador sea menor o igual al límite
while contador <= limite:

    # Se muestra el valor actual del contador
    print("Número:", contador)

    # El contador aumenta en 1
    contador = contador + 1
print("Programa realizado por Andres Jaquez NL = 27")
# Out:
# Ingresa el número límite: 5
# Número: 1
# Número: 2
# Número: 3
# Número: 4
# Número: 5
# Programa realizado por Andres Jaquez NL = 27

# %% [markdown]
# #2. Tabla de multiplicar con while
#
# ##Descripción:
# ##El ciclo while puede repetirse varias veces para mostrar operaciones matemáticas.
#
# ##Situación:
# ##Mostrar la tabla de multiplicar de un número.

# %%
# Programa realizado por Andres Jaquez NL = 27

# Se solicita un número
numero = int(input("Ingresa un número: "))

# Variable contador
contador = 1

# El ciclo se repetirá hasta el número 10
while contador <= 10:

    # Se realiza la multiplicación
    resultado = numero * contador

    # Se muestra el resultado
    print(numero, "x", contador, "=", resultado)

    # El contador aumenta en 1
    contador = contador + 1
print("Programa realizado por Andres Jaquez NL = 27")
# Out:
# Ingresa un número: 6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# Programa realizado por Andres Jaquez NL = 27

# %% [markdown]
# #3. Suma de números
#
# ##Descripción:
# ##El ciclo while permite acumular valores repetidamente.
#
# ##Situación:
# ##Sumar varios números ingresados por el usuario.

# %%
# Programa realizado por Andres Jaquez NL = 27

# Variable para guardar la suma
suma = 0

# Variable contador
contador = 1

# El ciclo se repetirá 5 veces
while contador <= 5:

    # Se solicita un número
    numero = int(input("Ingresa un número: "))

    # El número se agrega a la suma
    suma = suma + numero

    # El contador aumenta en 1
    contador = contador + 1

# Se muestra la suma total
print("La suma total es:", suma)
print("Programa realizado por Andres Jaquez NL = 27")
# Out:
# Ingresa un número: 7
# Ingresa un número: 3
# Ingresa un número: 5
# Ingresa un número: 4
# Ingresa un número: 7
# La suma total es: 26
# Programa realizado por Andres Jaquez NL = 27

# %% [markdown]
# #4. Contar letras de una palabra
#
# ##Descripción:
# ##El ciclo while puede recorrer caracteres de una palabra usando posiciones.
#
# ##Situación:
# ##Mostrar letra por letra una palabra.

# %%
# Programa realizado por Andres Jaquez NL = 27

# Se solicita una palabra
palabra = input("Ingresa una palabra: ")

# Variable contador
contador = 0

# El ciclo continuará mientras el contador sea menor al tamaño de la palabra
while contador < len(palabra):

    # Se muestra cada letra de la palabra
    print(palabra[contador])

    # El contador aumenta en 1
    contador = contador + 1
print("Programa realizado por Andres Jaquez NL = 27")
# Out:
# Ingresa una palabra: aguita
# a
# g
# u
# i
# t
# a
# Programa realizado por Andres Jaquez NL = 27

# %% [markdown]
# #5. Ciclo while
#
# ##Descripción:
# ##El ciclo while repite instrucciones mientras una condición sea verdadera.
# ##Situación: Contar números del 1 al 5.

# %%
# Programa realizado por Andres Jaquez NL = 27

# Se solicita un número inicial
numero = int(input("Ingresa el número inicial para comenzar la cuenta regresiva: "))

# El ciclo continuará mientras el número sea mayor o igual a 1
while numero >= 1:

    # Se muestra el número actual
    print("Cuenta regresiva:", numero)

    # El número disminuye en 1
    numero = numero - 1

# Mensaje final
print("Fin de la cuenta regresiva")
print("Programa realizado por Andres Jaquez NL = 27")
# Out:
# Ingresa el número inicial para comenzar la cuenta regresiva: 7
# Cuenta regresiva: 7
# Cuenta regresiva: 6
# Cuenta regresiva: 5
# Cuenta regresiva: 4
# Cuenta regresiva: 3
# Cuenta regresiva: 2
# Cuenta regresiva: 1
# Fin de la cuenta regresiva
# Programa realizado por Andres Jaquez NL = 27

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/AndresJaquez128/-UIII-Act2-ejemplos-ciclos-while-Andres-0074-Hombres-ciclo-while/refs/heads/main/UIII%20Act2%20infografiacicloWhile.png.png)
